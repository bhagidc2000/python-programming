# %%
Section 1: Identifiers


Explain why Python treats some identifiers as invalid.
Rewrite the invalid identifiers correctly.
Assign different valid identifiers to given values.
10
-5
3.14159
-0.12345
1000
"Hello, World!"
"Python"
"I am learning"
"Text type"
"String"
TRUE
FALSE



Section 2: Operators
1. Arithmetic Operators
Questions:
Define two variables and perform operations using arithmetic operators (+, -, *, /, //, %, **).
value1 = 10
value2 = 15

Add value1 and value2.
Subtract value1 from value2.
Multiply value1 and value2.
Divide value1 by value2.
Find the floor division of value1 by value2.
Find the remainder when dividing value1 by value2.
Calculate value1 raised to the power of value2.

You have a floor that is 95 meters long and 58.8 meter wide. Find out the total area using python and print it. 



2. Logical Operators
Questions:
Create a Python script that defines two boolean variables, is_sunny and is_warm, with appropriate values (True or False).
Use logical operators (and, or, not) to create the following conditions:
Check if it's both sunny and warm and print the result.
Check if it's either sunny or warm and print the result.
Check if it's not sunny and print the result.

3. Comparison Operators
Questions:
Create a Python script that defines two variables, value1 and value2, with any numeric values.
Use comparative operators (==, !=, <, >, <=, >=) to create the following conditions:
Check if value1 is equal to value2 and print the result.
Check if value1 is not equal to value2 and print the result.
Check if value1 is less than value2 and print the result.
Check if value1 is greater than value2 and print the result.
Check if value1 is less than or equal to value2 and print the result.
Check if value1 is greater than or equal to value2 and print the result.

# %% [markdown]
# Q1. Run the given identifiers and categorize them into valid and invalid ones.
#
# my_variable = 25
# counter = 40.7
# _total = "Hello"
# 123abc = 34
# my variable =6.7
# @count = "hi"
# for = "True"
# Name123 = 136
# myFunction = True
# _data = False
# if_condition? = "Innomatics"
# class = "Hyderabad"

# %%
# Valid
my_variable = 25
counter = 40.7
_total = "Hello"
Name123 = 136
myFunction = True
_data = False

# %%
# Invalid
123abc = 34
my variable =6.7 
for = "True"
if_condition? = "Innomatics"
class = "Hyderabad" 
@count = "hi"

# %%
Q2 . Explain why Python treats some identifiers as invalid.
Ans:
123abc=34 [ Its an invalid.Because its starts from a number.]   
my varible = 6.7 [ Its an invalid. Because threre is a space between my and variable.But we have use my_variable ]
for = "True"= [ Its an invalid.Because its an keyword ]
if_condition? = "Innomatics" [ Its an invalid.The resaon is used special characters.]
class = "Hyderabad"  = [ Its an invalid syntax ]
@count = "hi"=[ Its invalid.Because its start from special character]

# %%
 Q3. Rewrite the invalid identifiers correctly.
123abc = 34  
my_variable = 6.7  
for_keyword = "True"  
if_condition = "Innomatics"  
class_name = "Hyderabad"
count_value = "hi"
# Out:
#   Cell In[15], line 2
#     123abc = 34
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Q3. Assign different valid identifiers to given values.
# 10
# -5
# 3.14159
# -0.12345
# 1000
# "Hello, World!"
# "Python"
# "I am learning"
# "Text type"
# "String"
# TRUE
# FALSE

# %% [markdown]
# Section 2: Operators
# 1. Arithmetic Operators
# Questions:
# Define two variables and perform operations using arithmetic operators (+, -, *, /, //, %, **).
# value1 = 10
# value2 = 15

# %%
a=10
b=15
print(a+b)#addition
print(a-b)#subtraction
print(a*b)#multiplication
print(a/b)#division
print(a**b)#exponentiation
print(a//b)#floordivision
print(a%b)#moulus
# Out:
# 25
# -5
# 150
# 0.6666666666666666
# 1000000000000000
# 0
# 10

# %% [markdown]
#  2 . You have a floor that is 95 meters long and 58.8 meter wide. Find out the total area using python and print it.

# %%
length=95
breadth=58.8
total_area=(length*breadth)
print(total_area)
# Out:
# 5586.0

# %% [markdown]
# 2. Logical Operators

# %% [markdown]
# 1.Create a Python script that defines two boolean variables, is_sunny and is_warm, with appropriate values (True or False).Use logical operators (and, or, not) to create the following conditions:
# Check if it's both sunny and warm and print the result.
# Check if it's either sunny or warm and print the result.
# Check if it's not sunny and print the result.

# %%
is_sunny = True
is_warm = False
print(is_sunny and is_warm)
print(is_sunny or is_warm)
print(not is_sunny)
# Out:
# False
# True
# False

# %% [markdown]
# 3. Comparison Operators

# %% [markdown]
# 1.Create a Python script that defines two variables, value1 and value2, with any numeric values.Use comparative operators (==, !=, <, >, <=, >=) to create the following conditions

# %% [markdown]
# * Check if value1 is equal to value2 and print the result.
# * Check if value1 is not equal to value2 and print the result.
# * Check if value1 is less than value2 and print the result.
# * Check if value1 is greater than value2 and print the result.
# * Check if value1 is less than or equal to value2 and print the result.
# * Check if value1 is greater than or equal to value2 and print the result.

# %%
val1=81
val2=71
val1 == val2
# Out:
# False

# %%
val1
# Out:
# False

# %%
val1 != val2
# Out:
# True

# %%
val1  < val2
# Out:
# False

# %%
val1 > val2
# Out:
# True

# %%
val1 <=val2
# Out:
# False

# %%
val1 >= val2
# Out:
# True

# %% [markdown]
# Section 1: Identifiers

# %% [markdown]
# 4. Assign different valid identifiers to given values.

# %%
10
-5
3.14159
-0.12345
1000
"Hello, World!"
"Python"
"I am learning"
"Text type"
"String"
TRUE
FALSE

# %%
Ans:
positive_integer = 10  
negative_integer = -5  
pi_value = 3.14159  
negative_float = -0.12345  
large_number = 1000  
greeting_message = "Hello, World!"  
language = "Python"  
learning_statement = "I am learning"  
text_type = "Text type"  
string_example = "String"  
is_true = True  
is_false = False
